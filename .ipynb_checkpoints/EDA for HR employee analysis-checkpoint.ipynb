# %% [markdown]
# # EDA
# - EDA is a systematic approach to analyzing and visualizing data to uncover patterns, relationships, and anomalies.

# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
file_path = "HRData.csv"
df = pd.read_csv(file_path)

# %%
df
# Out:
#      EmployeeID      EmployeeName  Salary                  Position State  \
# 0             1        John Smith   62506   Production Technician I    MA
# 1             2     Sarah Johnson  104437                   Sr. DBA    MA
# 2             3  Michael Williams   64955  Production Technician II    MA
# 3             4       Emily Brown   64991   Production Technician I    MA
# 4             5       David Jones   50825   Production Technician I    MA
# ..          ...               ...     ...                       ...   ...
# 306         307        Nana Asare   65893  Production Technician II    MA
# 307         308        Yaa Yeboah   48513   Production Technician I    MA
# 308         309        Kojo Ofori  220450                       CIO    MA
# 309         310        Esi Amoako   89292              Data Analyst    MA
# 310         311       Kweku Annan   45046   Production Technician I    MA
#
#     DateOfBirth Gender MaritalStatus HiringDate TerminationDate  \
# ...

# %%
df.head()
# Out:
#    EmployeeID      EmployeeName  Salary                  Position State  \
# 0           1        John Smith   62506   Production Technician I    MA
# 1           2     Sarah Johnson  104437                   Sr. DBA    MA
# 2           3  Michael Williams   64955  Production Technician II    MA
# 3           4       Emily Brown   64991   Production Technician I    MA
# 4           5       David Jones   50825   Production Technician I    MA
#
#   DateOfBirth Gender MaritalStatus HiringDate TerminationDate  \
# 0    07/10/83     M         Single   7/5/2011             NaN
# 1    05/05/75     M        Married  3/30/2015       6/16/2016
# 2    09/19/88      F       Married   7/5/2011       9/24/2012
# 3    09/27/88      F       Married   1/7/2008             NaN
# 4    09/08/89      F      Divorced  7/11/2011        9/6/2016
#
#          EmploymentStatus         Department RecruitmentSource  \
# 0                  Active  Production                 LinkedIn
# ...

# %%
df.tail()
# Out:
#      EmployeeID EmployeeName  Salary                  Position State  \
# 306         307   Nana Asare   65893  Production Technician II    MA
# 307         308   Yaa Yeboah   48513   Production Technician I    MA
# 308         309   Kojo Ofori  220450                       CIO    MA
# 309         310   Esi Amoako   89292              Data Analyst    MA
# 310         311  Kweku Annan   45046   Production Technician I    MA
#
#     DateOfBirth Gender MaritalStatus HiringDate TerminationDate  \
# 306    05/11/85     M         Single   7/7/2014             NaN
# 307    05/04/82      F        Single   9/2/2008       9/29/2015
# 308    08/30/79      F        Single  4/10/2010             NaN
# 309    02/24/79      F        Single  3/30/2015             NaN
# 310    08/17/78      F       Widowed  9/29/2014             NaN
#
#            EmploymentStatus         Department  RecruitmentSource  \
# 306                  Active  Production                  LinkedIn
# ...

# %%
df.shape
# Out:
# (311, 16)

# %%
df.describe()
# Out:
#        EmployeeID         Salary  EngagementSurvey  EmployeeSatisfaction
# count  311.000000     311.000000        311.000000            311.000000
# mean   156.000000   69020.684887          4.110000              3.890675
# std     89.922189   25156.636930          0.789938              0.909241
# min      1.000000   45046.000000          1.120000              1.000000
# 25%     78.500000   55501.500000          3.690000              3.000000
# 50%    156.000000   62810.000000          4.280000              4.000000
# 75%    233.500000   72036.000000          4.700000              5.000000
# max    311.000000  250000.000000          5.000000              5.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   EmployeeID            311 non-null    int64
#  1   EmployeeName          311 non-null    object
#  2   Salary                311 non-null    int64
#  3   Position              311 non-null    object
#  4   State                 311 non-null    object
#  5   DateOfBirth           311 non-null    object
#  6   Gender                311 non-null    object
#  7   MaritalStatus         311 non-null    object
#  8   HiringDate            311 non-null    object
#  9   TerminationDate       104 non-null    object
#  10  EmploymentStatus      311 non-null    object
#  11  Department            311 non-null    object
#  12  RecruitmentSource     311 non-null    object
#  13  PerformanceScore      311 non-null    object
#  14  EngagementSurvey      311 non-null    float64
# ...

# %%
df.isnull().sum()
# Out:
# EmployeeID                0
# EmployeeName              0
# Salary                    0
# Position                  0
# State                     0
# DateOfBirth               0
# Gender                    0
# MaritalStatus             0
# HiringDate                0
# TerminationDate         207
# EmploymentStatus          0
# Department                0
# RecruitmentSource         0
# PerformanceScore          0
# EngagementSurvey          0
# EmployeeSatisfaction      0
# dtype: int64

# %%
# Convert date columns to datetime
date_columns = ['DateOfBirth', 'HiringDate', 'TerminationDate']
for col in date_columns:
    df[col] = pd.to_datetime(df[col], errors='coerce')

# Check for missing values and duplicates
missing_values = df.isnull().sum()
duplicates = df.duplicated().sum()

# Descriptive statistics for numerical columns
numerical_summary = df.describe()

# Unique value counts for categorical columns
categorical_summary = df.select_dtypes(include=['object']).nunique()

# %%
# Visualizations
plt.figure(figsize=(10, 6))
sns.histplot(df['Salary'], kde=True, bins=30, color='blue')
plt.title('Salary Distribution')
plt.xlabel('Salary')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Department', y='Salary', data=df)
plt.title('Salary by Department')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Gender', hue='PerformanceScore', data=df)
plt.title('Performance Score by Gender')
plt.show()

# %%
# Select only numerical columns for correlation
numerical_columns = df.select_dtypes(include=['number'])

# Calculate the correlation matrix
correlation_matrix = numerical_columns.corr()

plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ## Steps For EDA :
# Step 1: Define Objectives
# - Purpose: Understand why you are analyzing the data.
# Examples:
# - Identify patterns or trends (e.g., employee satisfaction vs. salary).
# - Uncover relationships between variables (e.g., engagement score and performance score).
# - Prepare data for predictive modelling.

# %% [markdown]
# Step 2: Data Inspection
#
# Load the data and inspect it.
# - Understand the structure of the dataset:
# - Number of rows and columns.
# - Column names and data types.
# - Preview a few rows to understand the format and values.

# %% [markdown]
# Step 3: Handle Missing Values
#
# - Identify missing data (check for NaN or blanks).
# - Quantify the missingness in each column.
# - Decide on a strategy:
# - Remove: Drop rows or columns with too many missing values.
# - Impute: Fill in missing values with mean, median, mode, or advanced techniques.

# %% [markdown]
# Step 4: Check Data Quality
#
# - Identify duplicates and remove them.
# - Look for inconsistent or incorrect entries (e.g., invalid dates or typos in categorical data).
# - Verify ranges for numerical data to spot outliers or unrealistic values.

# %% [markdown]
# Step 5: Univariate Analysis
#
# 1. For numerical variables:
# - Visualize: Use histograms, boxplots, or KDE plots.
# - Analyze: Look at measures like mean, median, and standard deviation.
#
# 2. For categorical variables:
# - Visualize: Use bar plots or pie charts.
# - Analyze: Count the frequency of each category.

# %% [markdown]
# Step 6: Prepare Data for Modeling
#
# - Encode categorical variables (e.g., one-hot encoding or label encoding).
# - Normalize or scale numerical variables if required.
# - Split the dataset into training and testing sets (if for machine learning).

# %% [markdown]
# Step 7: Visualize Insights
#
# - Choose appropriate charts (e.g., scatter plots for relationships, heatmaps for correlations).
# - Use dashboards or storytelling to present insights to stakeholders.
